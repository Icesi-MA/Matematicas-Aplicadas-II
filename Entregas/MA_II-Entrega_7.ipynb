# %% [markdown]
# # Entrega 7: Regla de la cadena y derivadas de orden superior
#
# **Departamento de Ciencias Físicas, Exactas & Energía / FIDCA**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->
#
# A continuación se le pide contestar o resolver por grupo las siguientes preguntas, utilizando una copia del presente cuaderno para consignar todas sus respuestas con el formato requerido.
#
# **Usted debe leer y trabajar en los problemas del cuaderno y traer preguntas para la sesión del miercoles 22 de octubre.**
#
# La entrega está para el día **viernes 24 de octubre** y todos los **grupos** estarán encargados de socializar sus resultados de acuerdo a los lineamientos entregados en la sesión del martes anterior.
#
# ## Nivel 3: Colaboración con IAG
#
# El estudiante puede apoyarse en IAG para redactar, sintetizar o clarificar entregables, siempre y cuando
# modifique activamente el contenido generado y lleve un registro de los prompts utilizados.
# Ejemplo: Uso de IAG para estructurar un Cuaderno Colab que involucre simulación de optimización en
# varias variables, explicando cómo se utilizó la herramienta y qué aportó al proceso.
#
# **<u>Preguntas</u>**
#
# A continuación encuentra separadas por celda cada pregunta, así usted solo debe continuar escribiendo en la celda para dar cada respuesta. No olvide que todas sus respuestas deben ir acompañadas de al menos un argumento geométrico o numérico y uno algebráico o en lenguaje natural.

# %% [markdown]
# 1. (30 ptos) **Regla de la cadena**
#
#
#   1.1 Exprese las derivadas indicadas de $f$ como un multiplo constante $c$ de $f$, si esto es posible.
#
#   a) $f(x,y)=e^{-x}\cos y,\quad f_{xx}+2f_{yy}= c f$
#
#   b) $f(x,t)=\sin (x-3t),\quad f_{x}-2f_{t}= c f$

# %% [markdown]
# 1.2  Considera la siguiente ecuación en derivadas parciales
# $$u_{t}+3u_{x}=0,\qquad (1)$$
# para una función diferenciable $u(x,t)$.
#
# a) Suponga que $f$ es una función diferenciable de una variable. Muestre que la función $u(x,t)=f(x-3t)$ satisface (1).
#
# b) Sea $V = \frac{1}{\sqrt{10}}(3,1)$. Demuestre que si $u(x, t)$ satisface (1) entonces la derivada direccional
# $D_Vu = 0$.
# (Aquí las coordenadas en $\mathbb{R}^2$ son $(x, t)$). Explique por qué $u$ es constante en líneas que son paralelas
# a $V$.
#
# (c) Demuestre que la línea que pasa por el punto $(x, t)$ y  es paralela a $V$ también pasa por el punto $(x−3t, 0)$.
#
# (d) Demuestre que toda solución $u(x, t)$ tiene la propiedad $u(x, t) = u(x − 3t, 0)$, es decir, es una
# función de $x−3t$.

# %% [markdown]
# 1.3 a) En un applet de GeoGebra dibuje la superficie  $$f(x,y)=x^3+3 x y+y^3$$
# y el plano tangente a la superficie en cualquier punto $(a,b)$.
#
# b) Describa como puede encontrar el o los puntos donde el plano tangente es horizontal. Halle dichos puntos.
#
# c) Clasifique los puntos donde el plano tangente es horizontal como máximos o mínimos locales o absolutos o puntos silla. Explique como llegó a esa clasificación.
#
# d) Encuentre las curvas de nivel que contienen a los puntos extremos (máximos o mínimos o puntos silla). Dibuje las curvas de nivel correspondientes y el vector gradiente en ese punto. Explique que relación geométrica tiene la curva y el vector gradiente en dicho punto.

# %% [markdown]
# 2. (20 ptos) **Derivadas de orden superior**.
#
#   2.1 Sea $\displaystyle f(x,y)=(x^2+y^2)^{3/2}$ calcule $f_{xx},f_{yy}$ y $f_{xy}$.

# %% [markdown]
#   2.2 Sea $\displaystyle f(\mathbf{x})=\cos(\mathbf{a}\cdot \mathbf{x})$ donde $\mathbf{x}\in\mathbb{R}^n$ y  $\mathbf{a}$ es un vector constante en $\mathbb{R}^n$. Esto es
#
#   $$f(x_1,...,x_n)=\cos(a_1x_1+...+a_nx_n).$$
#
#  Muestre que $$f_{x_1x_1}+...+f_{x_nx_n}=-||\mathbf{a}||^2f.$$

# %% [markdown]
# **La entrega solo se acepta en el formato de un cuaderno python colab .**
