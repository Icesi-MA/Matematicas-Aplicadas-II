# %% [markdown]
# # Combinaciones lineales y producto matriz-vector
#
# **Departamento de Ciencias Físicas, Exactas & Energía / FIDCA**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->
#
# **Descripción de la jornada**: En esta parte de la jornada usted va a encontrar un enunciado problema. Cada item del enunciado puede ser abordado en forma individual utilizando todos los recursos que usted disponga. La idea central es que elabore sus respuestas o construcciones siguiendo los lineamientos dados a continuación:
#
# 1. Escriba con claridad sus propias ideas.
# 2. Argumente usando lenguaje propio de las matemáticas: geométrico o algebraico, según sea el caso, cada una de sus respuestas.
# 3. Respalde donde considere conveniente sus argumentos geométricos y algebraicos con imágenes o applets diseñadas en alguna de las herramientas que hacen parte de la mochila digital.
# 4.	Resuelva los problemas de manera preferiblemente autónoma; describiendo estrategias para “atacar” el problema, poniendo a prueba sus soluciones y en lo posible planteando nuevos e “interesantes” interrogantes asociados al problema formulado. Si utiliza un resultado o teorema, este debe ser debidamente citado y si es un resultado ajeno a los estudiados en el curso o del texto guía debe proveer la respectiva demostración.
# 5. El uso de IA está permitido siempre y cuando sea usted quien reflexione y escriba su respuesta basado en su propio conocimiento. Resultados que no reflejen dicha reflexión recibirán una calificación de 0 y usted deberá sustentar oralmente su respuesta.

# %% [markdown]
# ## Combinación lineal y el producto Ax
#
# El siguiente Applet está diseñado de tal forma que puede obtener un nuevo vector $\mathbf{b}$ dando clic en el botón cuadrado.
#
# a. (15 puntos) Después de hacer click en el botón al menos un par de veces, escriba las coordenadas **aproximadas** del vector $\mathbf{b}$ que va a usar en este punto. Con respecto a dicho vector $\mathbf{b}$ debe encontrar la terna ordenada $(x,y,z)$ de forma tal que  $\mathbf{b}$ resulte ser el vector combinación lineal de los vectores $\mathbf{a}_i$, esto es,
#
# $$x\mathbf{a}_1+y\mathbf{a}_2+z\mathbf{a}_3=\mathbf{b}.$$
#
# Escriba esta combinación lineal utilizando la notación matricial $A\mathbf{x}=\mathbf{b}$, identificando claramente quién es la matriz $A$, el vector $\mathbf{x}$ y el vector $\mathbf{b}$, así como los respectivos tamaños de cada objeto.
#
# b. (10 puntos) En general, no solo con el vector $\mathbf{b}$ del punto anterior, sino para cualquier vector $\mathbf{b}$, ¿es siempre posible expresar $\mathbf{b}$ como una combinación lineal de los vectores $\mathbf{a}_i$ que aparecen en el applet?
#
# c. (20 puntos) Diseñe un applet por cada caso con dos vectores no nulos $\mathbf{v}_i$ distintos, de forma tal que: (i) el vector $\mathbf{b}$ no pueda ser  combinación lineal de ellos, y (ii) el vector $\mathbf{b}$ se obtenga de manera única como combinación lineal de ellos.
#
# d. (5 puntos) Si en el punto anterior, en lugar de usar dos vectores no nulos $\mathbf{v}_i$, utiliza tres, ¿sigue siendo única la combinación lineal?
#
# **Nota:** No olvide argumentar sus respuestas con base en los lineamientos previamente dados.

# %%
#@title Combinación lineal en el plano { display-mode: "form" }

import IPython.display as IP

iframe = IP.IFrame(
  src="https://www.geogebra.org/classic/bhjwxwnr",
  width="1020px",
  height="480px"
  )

IP.display_html(iframe)
# Out:
#         <iframe
#             width="1020px"
#             height="480px"
#             src="https://www.geogebra.org/classic/bhjwxwnr"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
