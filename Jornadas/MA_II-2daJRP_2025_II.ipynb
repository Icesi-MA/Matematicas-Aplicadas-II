# %% [markdown]
# # Espacios generados y matriz de covarianza
#
# **Departamento de Ciencias Físicas, Exactas & Energía / FIDCA**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->
#
# **Descripción de la jornada**: En esta parte de la jornada usted va a encontrar dos enunciados problema. Cada item de los enunciados pueden ser abordados en forma individual utilizando todos los recursos que usted disponga. La idea central es que elabore sus respuestas o construcciones siguiendo los lineamientos dados a continuación:
#
# 1. Escriba con claridad sus propias ideas.
# 2. Argumente usando lenguaje propio de las matemáticas: geométrico o algebraico, según sea el caso, cada una de sus respuestas.
# 3. Respalde donde considere conveniente sus argumentos geométricos y algebraicos con imágenes o applets diseñadas en alguna de las herramientas que hacen parte de la mochila digital.
# 4.	Resuelva los problemas de manera preferiblemente autónoma; describiendo estrategias para “atacar” el problema, poniendo a prueba sus soluciones y en lo posible planteando nuevos e “interesantes” interrogantes asociados al problema formulado. Si utiliza un resultado o teorema, este debe ser debidamente citado y si es un resultado ajeno a los estudiados en el curso o del texto guía debe proveer ejemplos propios relativos al problema que satisfagan el respectivo resultado.
# 5. Respuestas similares a otra de un compañero o posiblemente generadas con IA desde tendrán un valor asignado de 0 puntos y serán evaluadas en forma oral posterior a la finalización de la jornada.
#
# ## Nivel de uso de IAG 2: Planificación con IAG
# Se permite el uso de IAG únicamente en la fase de planificación o lluvia de ideas. El producto final debe
# ser completamente original y no contener contenido generado con IAG.
# Ejemplo: Exploración previa de posibles estrategias para resolver ecuaciones diferenciales separables o
# interpretar campos escalares, antes de construir la solución y justificarla por completo sin asistencia.

# %% [markdown]
# ## Espacios generados por vectores en $\mathbb{R}^3$

# %% [markdown]
# 1. Para este problema considere los siguientes vectores: $$
# \mathbf{a}_1 = \begin{pmatrix}
# 1 \\
# 0 \\
# -1
# \end{pmatrix}, \mathbf{a}_2 = \begin{pmatrix}
# 0 \\
# 1 \\
# 1
# \end{pmatrix}, \mathbf{a}_3 = \begin{pmatrix}
# 1 \\
# 1 \\
# 0
# \end{pmatrix}
# $$
#
# a. (5 puntos) Encuentre al menos un  vector no nulo $\mathbf{b}$ que sea combinación lineal de los vectores $\mathbf{a}_i,\, i =1,2,3$.
#
# b. (10 puntos) Escriba la combinación lineal del punto anterior utilizando la notación matricial $A\mathbf{x}=\mathbf{b}$, especificando claramente quién es la matriz $A$ y  el vector $\mathbf{x}$, así como los respectivos tamaños de cada objeto.
#
# c. (5 puntos) Muestre algebráicamente que el vector $ \mathbf{b_1} =\begin{pmatrix}
# 2 \\
# 1 \\
# 2
# \end{pmatrix}$ no puede ser generado por los vectores $\mathbf{a}_i,\, i =1,2,3$.
#
# d. (15 puntos) Diseñe un applet donde se vean los tres vectores $\mathbf{a}_i,\, i =1,2,3$, el vector $\mathbf{b}$  y el vector $\mathbf{b_1}$. Construya en el applet el espacio que generan los vectores $\mathbf{a}_i$ y uselo para explicar por qué $\mathbf{b}$ es generado por ellos pero $\mathbf{b}_1$ no. Finalmente, debe dar una representación algebráica del espacio generado por todos los vectores dados.
#
#
# e. (5 puntos) Si en la matriz $A$ del punto b, se sustituye uno de los vectores $\mathbf{a}_i$, por el vector $\mathbf{b}_1$, ¿se podría generar al vector $\mathbf{b}$ ?

# %% [markdown]
#  # Matriz de covarianza

# %% [markdown]
# 2. (10 ptos)  Considere los vectores del punto anterior y defina la matriz $A=[a_1\;a_2\;a_3]$.
#
#   a. Calcule el $3$-vector $\mu$ de las medias de las columnas, es decir,  $\mu_i = avg(a_i), i = 1,2,3$. Luego calcule los vectores $\tilde{a}_i=a_i-\mu_ie_i$ y defina $\tilde{A}$ como la matriz $\tilde{A}=[\tilde{a}_1\;\tilde{a}_2\;\tilde{a}_3]$
#
#   c. Calcule la matriz de *covarianza*  $\Sigma = (\frac{1}{3})\tilde{A}^T\tilde{A}$, de los vectores  $a_1,a_2,a_3$ y verifique que
#
#   $$\Sigma_{ij}=\begin{cases}
# \mathbf{std}(a_i)^2, & \text{ si } i=j\\
# \mathbf{std}(a_i)\,\mathbf{std}(a_j)\,\rho_{ij}, & \text{ si } i\not=j\end{cases}$$
#
# donde $\rho_{ij}$ es el coeficiente de correlación de $a_i$ y $a_j$.

# %% [markdown]
# **Nota:** No olvide argumentar sus respuestas con base en los lineamientos previamente dados.
